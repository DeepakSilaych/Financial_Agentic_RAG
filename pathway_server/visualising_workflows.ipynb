# %%
# !pip install -r ../requirements.txt

# %%
# !python --version
# Out:
# Python 3.11.10

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

import os
os.environ["OPENAI_API_KEY"]="iuwgduhbsw"
os.environ["TAVILY_API_KEY"]="iuwgduhbsw"
os.environ["COHERE_API_KEY"]="iuwgduhbsw"

import config

# %%
from workflows import e2e
display(
    Image(
        e2e.e2e.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='489404b6-b8b0-4cdb-88d0-0155d2fd3f1b'>
#   <div id="cc94e278-6d28-4faf-be1a-48c480cb0fab" data-root-id="489404b6-b8b0-4cdb-88d0-0155d2fd3f1b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import workflows.repeater_with_HITL as wf
display(
    Image(
        wf.rag_e2e.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import workflows.repeater_with_HITL as wf
#       2 display(
#       3     Image(
#       4         wf.rag_e2e.get_graph().draw_mermaid_png(
#    (...)
#       8     )
#       9 )
#
# File /mnt/c/Users/karth/OneDrive/DESKTOP/CODES/ML/PATHWAY/Pathway_High_Prep/workflows/repeater_with_HITL.py:645
#     641 graph.add_edge(START, nodes.check_safety.__name__)
#     642 graph.add_edge(nodes.check_safety.__name__, nodes.combine_conversation_history.__name__)
#     643 graph.add_conditional_edges(
#     644     nodes.combine_conversation_history.__name__,
# --> 645     edges.route_initial_query,
#     646     {
#     647         nodes.ask_clarifying_questions.__name__: nodes.ask_clarifying_questions.__name__,
#     648         nodes.general_llm.__name__: nodes.general_llm.__name__,
#     649     },
# ...

# %%
import workflows.repeater as wf
display(
    Image(
        wf.repeater.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import workflows.repeater as wf
#       2 display(
#       3     Image(
#       4         wf.repeater.get_graph().draw_mermaid_png(
#    (...)
#       8     )
#       9 )
#
# File /mnt/c/Users/karth/OneDrive/DESKTOP/CODES/ML/PATHWAY/Pathway_High_Prep/workflows/repeater.py:7
#       4 import json
#       6 import state, nodes, edges
# ----> 7 from nodes.question_decomposer import (
#       8     cache_retriever_call,
#       9     question_decomposer_v5,
#      10     question_decomposer_v6,
#      11     combine_questions_v3,
#      12     check_sufficient,
#      13 )
#      14 from .rag_e2e import rag_e2e
#      15 from state import QuestionNode
#
# ...

# %%
from workflows.split_path_decider import split_path_decider
display(
    Image(
        split_path_decider.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from workflows.split_path_decider import split_path_decider
#       2 display(
#       3     Image(
#       4         split_path_decider.get_graph().draw_mermaid_png(
#    (...)
#       8     )
#       9 )
#
# ModuleNotFoundError: No module named 'workflows.split_path_decider'

# %%
from config import WORKFLOW_SETTINGS
print(WORKFLOW_SETTINGS['semantic_cache'])

from workflows.rag_e2e import rag_e2e
display(
    Image(
        rag_e2e.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)
# Out:
# True

# %%
display(
    Image(
        final_workflow_with_path_decider.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
            curve_style=CurveStyle.NATURAL,
        )
    )
)

# %%
display(
    Image(
        with_hallucination_checker.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        naive_rag.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        with_metadata_extraction.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        Rerank1.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 display(
#       2     Image(
# ----> 3         Rerank1.get_graph().draw_mermaid_png(
#       4             draw_method=MermaidDrawMethod.API,
#       5         )
#       6     )
#       7 )
#
# NameError: name 'Rerank1' is not defined

# %%
display(
    Image(
        with_answer_grader.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        with_doc_relevance_only.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        with_doc_relevance.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        with_metadata_filtering.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        final_workflow.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        Rerank2.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
display(
    Image(
        visual_workflow.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
